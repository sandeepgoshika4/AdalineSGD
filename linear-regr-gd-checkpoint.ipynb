# %% [markdown]
# STAT 453: Deep Learning (Spring 2020)
# Instructor: Sebastian Raschka (sraschka@wisc.edu)
#
# Course website: http://pages.stat.wisc.edu/~sraschka/teaching/stat453-ss2020/
# GitHub repository: https://github.com/rasbt/stat453-deep-learning-ss20

# %%
# %load_ext watermark
# %watermark -a 'Sebastian Raschka' -v -p torch,pandas,matplotlib
# Out:
# Sebastian Raschka
#
# CPython 3.7.5
# IPython 7.10.2
#
# torch 1.4.0
# pandas 0.25.3
# matplotlib 3.1.1

# %% [markdown]
# # Linear Regression with Gradient Descent

# %% [markdown]
# ![](figures/adaline-concept.png)

# %% [markdown]
# Note that linear regression and Adaline are very similar. The only difference is that we apply a threshold function for converting the outputs from continuous targets for predictions. The derivative and training procedure are identical to Adaline though. You can compare the two notebooks (this one and `adaline-sgd.ipynb`) side by side as shown below to see the relationship:
#
# ![](figures/adaline-vs-linreg.png)

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.0.3-cp39-cp39-win_amd64.whl (10.8 MB)
#      ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#      - -------------------------------------- 0.4/10.8 MB 12.9 MB/s eta 0:00:01
#      ----------- ---------------------------- 3.0/10.8 MB 38.7 MB/s eta 0:00:01
#      ----------- ---------------------------- 3.1/10.8 MB 28.3 MB/s eta 0:00:01
#      ----------- ---------------------------- 3.2/10.8 MB 20.6 MB/s eta 0:00:01
#      ------------ --------------------------- 3.3/10.8 MB 15.2 MB/s eta 0:00:01
#      ------------- -------------------------- 3.6/10.8 MB 13.6 MB/s eta 0:00:01
#      -------------- ------------------------- 4.0/10.8 MB 12.8 MB/s eta 0:00:01
#      ---------------- ----------------------- 4.5/10.8 MB 12.4 MB/s eta 0:00:01
#      ------------------ --------------------- 5.1/10.8 MB 12.0 MB/s eta 0:00:01
#      ----------------------- ---------------- 6.3/10.8 MB 13.9 MB/s eta 0:00:01
#      ----------------------- ---------------- 6.3/10.8 MB 13.9 MB/s eta 0:00:01
#      ----------------------- ---------------- 6.3/10.8 MB 11.6 MB/s eta 0:00:01
#      ------------------------ --------------- 6.5/10.8 MB 11.2 MB/s eta 0:00:01
#      ------------------------- -------------- 6.9/10.8 MB 10.7 MB/s eta 0:00:01
#      --------------------------- ------------ 7.3/10.8 MB 10.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 7.8/10.8 MB 10.6 MB/s eta 0:00:01
#      ------------------------------- -------- 8.6/10.8 MB 10.7 MB/s eta 0:00:01
#      --------------------------------------  10.8/10.8 MB 13.4 MB/s eta 0:00:01
#      --------------------------------------- 10.8/10.8 MB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\siu856511631\appdata\local\anaconda3\envs\rcnn\lib\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2020.1
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      ---------------------------------------- 0.0/502.3 kB ? eta -:--:--
#      ---------------------------------------- 502.3/502.3 kB ? eta 0:00:00
# Requirement already satisfied: numpy>=1.20.3 in c:\users\siu856511631\appdata\local\anaconda3\envs\rcnn\lib\site-packages (from pandas) (1.24.3)
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ---------------------------------------- 0.0/341.8 kB ? eta -:--:--
#      ---------------------------------------- 341.8/341.8 kB ? eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\siu856511631\appdata\local\anaconda3\envs\rcnn\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.0.3 pytz-2023.3 tzdata-2023.3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import torch
# %matplotlib inline

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## Load & Prepare a Toy Dataset

# %%
df = pd.read_csv('ENB2012_data.csv', index_col=0)
df.tail()
# Out:
#          X2     X3     X4   X5  X6   X7  X8     Y1     Y2
# X1
# 0.64  784.0  343.0  220.5  3.5   5  0.4   5  17.88  21.40
# 0.62  808.5  367.5  220.5  3.5   2  0.4   5  16.54  16.88
# 0.62  808.5  367.5  220.5  3.5   3  0.4   5  16.44  17.11
# 0.62  808.5  367.5  220.5  3.5   4  0.4   5  16.48  16.61
# 0.62  808.5  367.5  220.5  3.5   5  0.4   5  16.64  16.03

# %%
# Assign features and target

X = torch.tensor(df.drop(columns=["Y1", "Y2"]).values, dtype=torch.float)
y = torch.tensor(df['Y2'].values, dtype=torch.float)

# Shuffling & train/test split

torch.manual_seed(123)
shuffle_idx = torch.randperm(y.size(0), dtype=torch.long)

X, y = X[shuffle_idx], y[shuffle_idx]

percent80 = int(shuffle_idx.size(0)*0.8)

X_train, X_test = X[shuffle_idx[:percent80]], X[shuffle_idx[percent80:]]
y_train, y_test = y[shuffle_idx[:percent80]], y[shuffle_idx[percent80:]]

# Normalize (mean zero, unit variance)

mu, sigma = X_train.mean(dim=0), X_train.std(dim=0)
X_train = (X_train - mu) / sigma
X_test = (X_test - mu) / sigma

# %%
px = pd.DataFrame(X_train.numpy())
px.head()
# Out:
#           0         1         2         3         4         5         6
# 0  0.173944 -1.719913  0.980692 -1.008997  1.354428  0.100525  0.143824
# 1 -0.645504  0.008445 -0.643800  0.989469 -1.316724  0.100525  0.143824
# 2 -0.099205  2.312922 -1.185297  0.989469  1.354428 -1.021704 -1.136004
# 3 -1.738100 -0.567674 -1.456046  0.989469  1.354428  1.222755 -0.496090
# 4 -0.918653 -0.567674 -0.643800  0.989469  0.464044 -1.021704  0.143824

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## Implement Linear Regression Model

# %%
fig, axes = plt.subplots(1,len(df.columns.values)-2, sharey=True, figsize=(12,8))

for i, col in enumerate(df.columns.values[:-2]):
    df.plot(x=[col], y=["Y2"], kind="scatter", ax=axes[i])

plt.show()

# %%
class LinearRegression1():
    def __init__(self, num_features):
        self.num_features = num_features
        self.weights = torch.zeros(num_features, 1, 
                                   dtype=torch.float)
        self.bias = torch.zeros(1, dtype=torch.float)

    def forward(self, x):
        netinputs = torch.add(torch.mm(x, self.weights), self.bias)
        activations = netinputs
        return activations.view(-1)
        
    def backward(self, x, yhat, y):  
        
        grad_loss_yhat = 2*(y - yhat)
        
        grad_yhat_weights = -x
        grad_yhat_bias = -1.
        
        # Chain rule: inner times outer
        grad_loss_weights =  torch.mm(grad_yhat_weights.t(),
                                         grad_loss_yhat.view(-1, 1)) / y.size(0)

        grad_loss_bias = torch.sum(grad_yhat_bias*grad_loss_yhat) / y.size(0)
        
        # return negative gradient
        return (-1)*grad_loss_weights, (-1)*grad_loss_bias

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## Define Training and Evaluation Functions

# %%
####################################################
##### Training and evaluation wrappers
###################################################

def loss(yhat, y):
    return torch.mean((yhat - y)**2)


def train(model, x, y, num_epochs, learning_rate=0.05):
    cost = []
    for e in range(num_epochs):

        #### Compute outputs ####
        yhat = model.forward(x)

        #### Compute gradients ####
        negative_grad_w, negative_grad_b = model.backward(x, yhat, y)

        #### Update weights ####
        model.weights += learning_rate * negative_grad_w
        model.bias += learning_rate * negative_grad_b

        #### Logging ####
        yhat = model.forward(x) # not that this is a bit wasteful here
        curr_loss = loss(yhat, y)
        print('Epoch: %03d' % (e+1), end="")
        print(' | MSE: %.5f' % curr_loss)
        cost.append(curr_loss)

    return cost

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# 
# Epoch: 463 | MSE: 10.08267
# Epoch: 464 | MSE: 10.08207
# Epoch: 465 | MSE: 10.08147
# Epoch: 466 | MSE: 10.08088
# Epoch: 467 | MSE: 10.08029
# Epoch: 468 | MSE: 10.07971
# Epoch: 469 | MSE: 10.07913
# Epoch: 470 | MSE: 10.07855
# Epoch: 471 | MSE: 10.07798
# Epoch: 472 | MSE: 10.07742
# Epoch: 473 | MSE: 10.07685
# Epoch: 474 | MSE: 10.07629
# Epoch: 475 | MSE: 10.07574
# Epoch: 476 | MSE: 10.07519
# Epoch: 477 | MSE: 10.07464
# Epoch: 478 | MSE: 10.07410
# Epoch: 479 | MSE: 10.07356
# Epoch: 480 | MSE: 10.07303
# Epoch: 481 | MSE: 10.07250
# Epoch: 482 | MSE: 10.07197
# Epoch: 483 | MSE: 10.07145
# Epoch: 484 | MSE: 10.07093
# Epoch: 485 | MSE: 10.07041
# Epoch: 486 | MSE: 10.06990
# Epoch: 487 | MSE: 10.06939
# Epoch: 488 | MSE: 10.06889
# Epoch: 489 | MSE: 10.06839
# Epoch: 490 | MSE: 10.06789
# Epoch: 491 | MSE: 10.06739
# Epoch: 492 | MSE: 10.06691
# Epoch: 493 | MSE: 10.06642
# Epoch: 494 | MSE: 10.06594
# Epoch: 495 | MSE: 10.06546
# Epoch: 496 | MSE: 10.06498
# Epoch: 497 | MSE: 10.06451
# Epoch: 498 | MSE: 10.06404
# Epoch: 499 | MSE: 10.06357
# Epoch: 500 | MSE: 10.06311

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## Evaluate Linear Regression Model

# %% [markdown]
# ### Plot MSE

# %%
plt.plot(range(len(cost)), cost)
plt.ylabel('Mean Squared Error')
plt.xlabel('Epoch')
plt.show()

# %%
train_pred = model.forward(X_train)
test_pred = model.forward(X_test)

print('Train MSE: %.5f' % loss(train_pred, y_train))
print('Test MSE: %.5f' % loss(test_pred, y_test))
# Out:
# Train MSE: 10.06311
# Test MSE: 13.97574

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ### Compare with analytical solution

# %%
print('Weights', model.weights)
print('Bias', model.bias)
# Out:
# Weights tensor([[ 0.6670],
#         [ 1.5029],
#         [-0.0452],
#         [ 8.4695],
#         [ 0.1804],
#         [ 2.0061],
#         [ 0.0317]])
# Bias tensor([24.5209])

# %%
def analytical_solution(x, y):
    Xb = torch.cat( (torch.ones((x.size(0), 1)), x), dim=1)
    w = torch.zeros(x.size(1))
    z = torch.inverse(torch.matmul(Xb.t(), Xb))
    params = torch.matmul(z, torch.matmul(Xb.t(), y))
    b, w = torch.tensor([params[0]]), params[1:].view(x.size(1), 1)
    return w, b

w, b = analytical_solution(X_train, y_train)
print('Analytical weights', w)
print('Analytical bias', b)
# Out:
# Analytical weights tensor([[ 1.7866e+02],
#         [-6.7601e+01],
#         [-1.5184e+02],
#         [ 1.0946e+01],
#         [ 1.8448e-01],
#         [ 1.9889e+00],
#         [ 3.5812e-02]])
# Analytical bias tensor([24.5209])

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## (Ungraded) HW Exercises

# %% [markdown]
# Modify the `train()` function such that the dataset is shuffled prior to each epoch. Do you see a difference -- Yes/No? Try to come up with an explanation for your observation.
